# %% [markdown]
# <a href="https://colab.research.google.com/github/Dexne/Pattern_Recognition/blob/main/08_GLM_con_statsmodels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reconocimiento de patrones**
#
# Modelos Lineales Generalizados con statsmodels
# Primeramente instalamos la paquetería

# %%
pip install statsmodels

# %% [markdown]
# **Modelo Gamma**
#
# Ejemplo tomado de https://www.statsmodels.org/stable/examples/notebooks/generated/glm.html
#
# Importamos paqueterias

# %%
import numpy as np
import statsmodels.api as sm
from scipy import stats
from matplotlib import pyplot as plt

# %% [markdown]
# Cargamos datos desde la misma API

# %%
print(sm.datasets.star98.NOTE)
# Out:
# ::
#
#     Number of Observations - 303 (counties in California).
#
#     Number of Variables - 13 and 8 interaction terms.
#
#     Definition of variables names::
#
#         NABOVE   - Total number of students above the national median for the
#                    math section.
#         NBELOW   - Total number of students below the national median for the
#                    math section.
#         LOWINC   - Percentage of low income students
#         PERASIAN - Percentage of Asian student
#         PERBLACK - Percentage of black students
#         PERHISP  - Percentage of Hispanic students
#         PERMINTE - Percentage of minority teachers
#         AVYRSEXP - Sum of teachers' years in educational service divided by the
#                 number of teachers.
#         AVSALK   - Total salary budget including benefits divided by the number
#                    of full-time teachers (in thousands)
#         PERSPENK - Per-pupil spending (in thousands)
# ...

# %%
data = sm.datasets.star98.load()
data.exog = sm.add_constant(data.exog, prepend=False)

# %% [markdown]
# Variables de entrada

# %%
data.exog
# Out:
#        LOWINC   PERASIAN   PERBLACK    PERHISP   PERMINTE  AVYRSEXP    AVSALK  \
# 0    34.39730  23.299300  14.235280  11.411120  15.918370  14.70646  59.15732
# 1    17.36507  29.328380   8.234897   9.314884  13.636360  16.08324  59.50397
# 2    32.64324   9.226386  42.406310  13.543720  28.834360  14.59559  60.56992
# 3    11.90953  13.883090   3.796973  11.443110  11.111110  14.38939  58.33411
# 4    36.88889  12.187500  76.875000   7.604167  43.589740  13.90568  63.15364
# ..        ...        ...        ...        ...        ...       ...       ...
# 298  62.23968  13.820860   3.956157  32.128790  15.884480  13.27089  52.88133
# 299  46.16188   1.150575   0.800400  45.622810  13.333330  11.80714  48.42615
# 300  43.41431   3.648564   1.541204  46.319980  21.377670  14.40468  53.79616
# 301  70.62104  20.461720   2.989345  17.423050  11.032860  16.56420  61.70566
# 302  77.74827   5.998899   9.576225  11.117230   7.874016  16.91871  65.09957
#
# ...

# %% [markdown]
# variables de salida

# %%
print(data.endog)
# Out:
#      NABOVE  NBELOW
# 0     452.0   355.0
# 1     144.0    40.0
# 2     337.0   234.0
# 3     395.0   178.0
# 4       8.0    57.0
# ..      ...     ...
# 298    96.0   246.0
# 299    37.0   117.0
# 300   208.0   387.0
# 301   199.0   510.0
# 302    72.0    84.0
#
# [303 rows x 2 columns]

# %% [markdown]
# crear modelo y entrenar

# %%
glm_binom = sm.GLM(data.endog, data.exog, family=sm.families.Binomial())
res = glm_binom.fit()
print(res.summary())
# Out:
#                   Generalized Linear Model Regression Results
# ...
# Dep. Variable:     ['NABOVE', 'NBELOW']   No. Observations:                  303
# Model:                              GLM   Df Residuals:                      282
# Model Family:                  Binomial   Df Model:                           20
# Link Function:                    Logit   Scale:                          1.0000
# Method:                            IRLS   Log-Likelihood:                -2998.6
# Date:                  Tue, 07 May 2024   Deviance:                       4078.8
# Time:                          16:33:44   Pearson chi2:                 4.05e+03
# No. Iterations:                       5   Pseudo R-squ. (CS):              1.000
# Covariance Type:              nonrobust
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Regresión Poisson**
#
# Ejemplo tomado de https://timeseriesreasoning.com/contents/poisson-regression-model/

# %%
import pandas as pd
from patsy import dmatrices
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/nyc_bb_bicyclist_counts.csv', header=0, infer_datetime_format=True, parse_dates=[0], index_col=[0])
# Out:
# <ipython-input-9-5b6a8c02da5c>:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv('/content/nyc_bb_bicyclist_counts.csv', header=0, infer_datetime_format=True, parse_dates=[0], index_col=[0])
# <ipython-input-9-5b6a8c02da5c>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('/content/nyc_bb_bicyclist_counts.csv', header=0, infer_datetime_format=True, parse_dates=[0], index_col=[0])

# %%
df.head()
# Out:
#             HIGH_T  LOW_T  PRECIP  BB_COUNT
# Date
# 2017-04-01    46.0   37.0    0.00       606
# 2017-04-02    62.1   41.0    0.00      2021
# 2017-04-03    63.0   50.0    0.03      2470
# 2017-04-04    51.1   46.0    1.18       723
# 2017-04-05    63.0   46.0    0.00      2807

# %%
ds = df.index.to_series()
df['MONTH'] = ds.dt.month
df['DAY_OF_WEEK'] = ds.dt.dayofweek
df['DAY'] = ds.dt.day

# %%
mask = np.random.rand(len(df)) < 0.8
df_train = df[mask]
df_test = df[~mask]
print('Training data set length='+str(len(df_train)))
print('Testing data set length='+str(len(df_test)))
# Out:
# Training data set length=180
# Testing data set length=34

# %%
expr = """BB_COUNT ~ DAY  + DAY_OF_WEEK + MONTH + HIGH_T + LOW_T + PRECIP"""

# %%
ytrain, xtrain = dmatrices(expr, df_train, return_type='dataframe')
ytest,xtest = dmatrices(expr, df_test, return_type='dataframe')

# %%
poisson_training_results = sm.GLM(ytrain, xtrain, family=sm.families.Poisson()).fit()

# %%
print(poisson_training_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               BB_COUNT   No. Observations:                  180
# Model:                            GLM   Df Residuals:                      173
# Model Family:                 Poisson   Df Model:                            6
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -13003.
# Date:                Tue, 07 May 2024   Deviance:                       24270.
# Time:                        16:36:26   Pearson chi2:                 2.39e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       7.0313      0.012    588.675      0.000       7.008       7.055
# ...

# %%
poisson_predictions = poisson_training_results.get_prediction(xtest)
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)
# Out:
#                    mean    mean_se  mean_ci_lower  mean_ci_upper
# Date
# 2017-04-08  2323.560011  10.277578    2303.503393    2343.791262
# 2017-04-25  1056.487937   7.337877    1042.203410    1070.968249
# 2017-04-30  2315.646977  10.320742    2295.506788    2335.963870
# 2017-05-10  2975.175954   9.515955    2956.583362    2993.885466
# 2017-05-19  3279.700750  11.514109    3257.210974    3302.345809
# 2017-05-23  2665.735721   8.100153    2649.906896    2681.659098
# 2017-05-29  2005.768491  10.170657    1985.933099    2025.801998
# 2017-06-01  3042.998567   9.265173    3024.893238    3061.212264
# 2017-06-18  2901.597708   9.919131    2882.221552    2921.104124
# 2017-06-21  3019.762008   8.416002    3003.311915    3036.302203
# 2017-06-22  3048.220109   7.403800    3033.743415    3062.765885
# 2017-06-23  2733.203668  10.182359    2713.319294    2753.233763
# 2017-06-25  2922.184827   9.984483    2902.680979    2941.819726
# ...
