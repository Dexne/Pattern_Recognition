# %% [markdown]
# <a href="https://colab.research.google.com/github/Dexne/Pattern_Recognition/blob/main/01_Regresion_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reconocimiento de patrones**
#
# **Método directo**
#
# Primero vamos a crear un conjunto de datos para una regresión lineal simple

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p = 100
ruido = 3
x = -1 + 2 * np.random.rand(p).reshape(1,-1)
Y = -18 * x + 6 + ruido * np.random.randn(p)
plt.plot(x, Y,'.b')
plt.show()

# %% [markdown]
# Hacemos una regresión lineal

# %%
X = np.concatenate((np.ones((1,p)), x), axis=0)
theta = np.dot(Y.reshape(1,-1), np.linalg.pinv(X))
print(theta)
# Out:
# [[  5.54616591 -17.88206456]]

# %% [markdown]
# Dibujamos la linea de regresión

# %%
Xnew = np.array([[1,  1],
                 [-1, 1]])
Ynew = theta @ Xnew

plt.figure()
plt.plot(x, Y,'.b')
plt.plot(Xnew[1,:].ravel(), Ynew.ravel(), '--r')
plt.show()
